# %% [markdown]
# <a href="https://colab.research.google.com/github/Rogerio-mack/Analise_de_Dados_2023S2/blob/main/Aula_20231011.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <head>
#   <meta name="author" content="Rogério de Oliveira">
#   <meta institution="author" content="Universidade Presbiteriana Mackenzie">
# </head>
#
# <img src="http://meusite.mackenzie.br/rogerio/mackenzie_logo/UPM.2_horizontal_vermelho.jpg" width=300, align="right">
# <!-- <h1 align=left><font size = 6, style="color:rgb(200,0,0)"> optional title </font></h1> -->

# %% [markdown]
# # Lab: Aula online

# %% [markdown]
# # Basic imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# # **Fatalities in the Israeli-Palestinian Conflict**

# %%
df = pd.read_csv('https://github.com/Rogerio-mack/Analise_de_Dados_2023S2/raw/main/fatalities_isr_pse_conflict_2000_to_2023.csv')
df.head()
# Out:
#                                           name date_of_event   age  \
# 0  'Abd a-Rahman Suleiman Muhammad Abu Daghash    2023-09-24  32.0
# 1         Usayed Farhan Muhammad 'Ali Abu 'Ali    2023-09-24  21.0
# 2             'Abdallah 'Imad Sa'ed Abu Hassan    2023-09-22  16.0
# 3             Durgham Muhammad Yihya al-Akhras    2023-09-20  19.0
# 4                 Raafat 'Omar Ahmad Khamaisah    2023-09-19  15.0
#
#    citizenship     event_location event_location_district  \
# 0  Palestinian     Nur Shams R.C.                 Tulkarm
# 1  Palestinian     Nur Shams R.C.                 Tulkarm
# 2  Palestinian           Kfar Dan                   Jenin
# 3  Palestinian  'Aqbat Jaber R.C.                 Jericho
# 4  Palestinian         Jenin R.C.                   Jenin
#
#   event_location_region date_of_death gender took_part_in_the_hostilities  \
# 0             West Bank    2023-09-24      M                          NaN
# 1             West Bank    2023-09-24      M                          NaN
# 2             West Bank    2023-09-22      M                          NaN
# 3             West Bank    2023-09-20      M                          NaN
# 4             West Bank    2023-09-19      M                          NaN
#
#   place_of_residence place_of_residence_district type_of_injury  \
# 0     Nur Shams R.C.                     Tulkarm        gunfire
# 1     Nur Shams R.C.                     Tulkarm        gunfire
# 2           al-Yamun                       Jenin        gunfire
# 3  'Aqbat Jaber R.C.                     Jericho        gunfire
# 4              Jenin                       Jenin        gunfire
#
#         ammunition                killed_by  \
# 0  live ammunition  Israeli security forces
# 1  live ammunition  Israeli security forces
# 2  live ammunition  Israeli security forces
# 3  live ammunition  Israeli security forces
# 4  live ammunition  Israeli security forces
#
#                                                notes
# 0  Fatally shot by Israeli forces while standing ...
# 1  Fatally shot by Israeli forces while trying to...
# 2  Fatally shot by soldiers while firing at them ...
# 3  Shot in the head by Israeli forces while throw...
# 4  Wounded by soldiers’ gunfire after running awa...

# %% [markdown]
# ## Exploração inicial dos dados

# %%
df.shape
# Out:
# (11124, 16)

# %%
len(df)
# Out:
# 11124

# %%
df.columns
# Out:
# Index(['name', 'date_of_event', 'age', 'citizenship', 'event_location',
#        'event_location_district', 'event_location_region', 'date_of_death',
#        'gender', 'took_part_in_the_hostilities', 'place_of_residence',
#        'place_of_residence_district', 'type_of_injury', 'ammunition',
#        'killed_by', 'notes'],
#       dtype='object')

# %%
df.dtypes
# Out:
# name                             object
# date_of_event                    object
# age                             float64
# citizenship                      object
# event_location                   object
# event_location_district          object
# event_location_region            object
# date_of_death                    object
# gender                           object
# took_part_in_the_hostilities     object
# place_of_residence               object
# place_of_residence_district      object
# type_of_injury                   object
# ammunition                       object
# killed_by                        object
# notes                            object
# dtype: object

# %%
df.describe(include='all')
# Out:
#                             name date_of_event           age  citizenship  \
# count                      11124         11124  10995.000000        11124
# unique                     11083          2405           NaN            4
# top     Name unknown to B'Tselem    2008-12-27           NaN  Palestinian
# freq                          23           357           NaN        10092
# mean                         NaN           NaN     26.745703          NaN
# std                          NaN           NaN     13.780548          NaN
# min                          NaN           NaN      1.000000          NaN
# 25%                          NaN           NaN     19.000000          NaN
# 50%                          NaN           NaN     23.000000          NaN
# 75%                          NaN           NaN     31.000000          NaN
# max                          NaN           NaN    112.000000          NaN
#
#        event_location event_location_district event_location_region  \
# count           11124                   11124                 11124
# unique            494                      20                     3
# top         Gaza City                    Gaza            Gaza Strip
# freq             2232                    2435                  7733
# mean              NaN                     NaN                   NaN
# std               NaN                     NaN                   NaN
# min               NaN                     NaN                   NaN
# 25%               NaN                     NaN                   NaN
# 50%               NaN                     NaN                   NaN
# 75%               NaN                     NaN                   NaN
# max               NaN                     NaN                   NaN
#
#        date_of_death gender took_part_in_the_hostilities place_of_residence  \
# count          11124  11104                         9694              11056
# unique          2593      2                            5                580
# top       2008-12-27      M                           No          Gaza city
# freq             341   9681                         4653               2283
# mean             NaN    NaN                          NaN                NaN
# std              NaN    NaN                          NaN                NaN
# min              NaN    NaN                          NaN                NaN
# 25%              NaN    NaN                          NaN                NaN
# 50%              NaN    NaN                          NaN                NaN
# 75%              NaN    NaN                          NaN                NaN
# max              NaN    NaN                          NaN                NaN
#
#        place_of_residence_district type_of_injury ammunition  \
# count                        11056          10833       5871
# unique                          20             13         21
# top                           Gaza        gunfire    missile
# freq                          2453           9849       2877
# mean                           NaN            NaN        NaN
# std                            NaN            NaN        NaN
# min                            NaN            NaN        NaN
# 25%                            NaN            NaN        NaN
# 50%                            NaN            NaN        NaN
# 75%                            NaN            NaN        NaN
# max                            NaN            NaN        NaN
#
#                       killed_by                                        notes
# count                     11124                                        10844
# unique                        3                                         6744
# top     Israeli security forces  Killed during "Operation Defensive Shield."
# freq                      10000                                          113
# mean                        NaN                                          NaN
# std                         NaN                                          NaN
# min                         NaN                                          NaN
# 25%                         NaN                                          NaN
# 50%                         NaN                                          NaN
# 75%                         NaN                                          NaN
# max                         NaN                                          NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11124 entries, 0 to 11123
# Data columns (total 16 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   name                          11124 non-null  object
#  1   date_of_event                 11124 non-null  object
#  2   age                           10995 non-null  float64
#  3   citizenship                   11124 non-null  object
#  4   event_location                11124 non-null  object
#  5   event_location_district       11124 non-null  object
#  6   event_location_region         11124 non-null  object
#  7   date_of_death                 11124 non-null  object
#  8   gender                        11104 non-null  object
#  9   took_part_in_the_hostilities  9694 non-null   object
#  10  place_of_residence            11056 non-null  object
#  11  place_of_residence_district   11056 non-null  object
#  12  type_of_injury                10833 non-null  object
#  13  ammunition                    5871 non-null   object
#  14  killed_by                     11124 non-null  object
#  15  notes                         10844 non-null  object
# dtypes: float64(1), object(15)
# memory usage: 1.4+ MB

# %% [markdown]
# # Seleção de Uma Coluna

# %%
list(df.columns)
# Out:
# ['name',
#  'date_of_event',
#  'age',
#  'citizenship',
#  'event_location',
#  'event_location_district',
#  'event_location_region',
#  'date_of_death',
#  'gender',
#  'took_part_in_the_hostilities',
#  'place_of_residence',
#  'place_of_residence_district',
#  'type_of_injury',
#  'ammunition',
#  'killed_by',
#  'notes']

# %%
df.killed_by
# Out:
# 0        Israeli security forces
# 1        Israeli security forces
# 2        Israeli security forces
# 3        Israeli security forces
# 4        Israeli security forces
#                   ...
# 11119      Palestinian civilians
# 11120          Israeli civilians
# 11121      Palestinian civilians
# 11122          Israeli civilians
# 11123      Palestinian civilians
# Name: killed_by, Length: 11124, dtype: object

# %%
df['killed_by']
# Out:
# 0        Israeli security forces
# 1        Israeli security forces
# 2        Israeli security forces
# 3        Israeli security forces
# 4        Israeli security forces
#                   ...
# 11119      Palestinian civilians
# 11120          Israeli civilians
# 11121      Palestinian civilians
# 11122          Israeli civilians
# 11123      Palestinian civilians
# Name: killed_by, Length: 11124, dtype: object

# %%
for c in ['event_location', 'event_location_district', 'killed_by']:
  print(df[c].mode())
# Out:
# 0    Gaza City
# Name: event_location, dtype: object
# 0    Gaza
# Name: event_location_district, dtype: object
# 0    Israeli security forces
# Name: killed_by, dtype: object

# %%
df['killed_by'].unique()
# Out:
# array(['Israeli security forces', 'Palestinian civilians',
#        'Israeli civilians'], dtype=object)

# %%
df['killed_by'].nunique()
# Out:
# 3

# %%
df['killed_by'].value_counts()
# Out:
# Israeli security forces    10000
# Palestinian civilians       1028
# Israeli civilians             96
# Name: killed_by, dtype: int64

# %%
df['age'].mean(), df['age'].var(), df['age'].min()
# Out:
# (26.745702592087312, 189.9034913996249, 1.0)

# %%
df['age'].value_counts()
# Out:
# 22.0     630
# 21.0     610
# 20.0     589
# 23.0     581
# 19.0     534
#         ...
# 112.0      1
# 91.0       1
# 89.0       1
# 92.0       1
# 88.0       1
# Name: age, Length: 95, dtype: int64

# %%
plt.hist(df.age)
plt.show()

# %% [markdown]
# ## Seleção de mais de um coluna

# %%
df.columns
# Out:
# Index(['name', 'date_of_event', 'age', 'citizenship', 'event_location',
#        'event_location_district', 'event_location_region', 'date_of_death',
#        'gender', 'took_part_in_the_hostilities', 'place_of_residence',
#        'place_of_residence_district', 'type_of_injury', 'ammunition',
#        'killed_by', 'notes'],
#       dtype='object')

# %%
df[['age', 'citizenship', 'killed_by']]
# Out:
#         age  citizenship                killed_by
# 0      32.0  Palestinian  Israeli security forces
# 1      21.0  Palestinian  Israeli security forces
# 2      16.0  Palestinian  Israeli security forces
# 3      19.0  Palestinian  Israeli security forces
# 4      15.0  Palestinian  Israeli security forces
# ...     ...          ...                      ...
# 11119  64.0      Israeli    Palestinian civilians
# 11120  28.0  Palestinian        Israeli civilians
# 11121  36.0      Israeli    Palestinian civilians
# 11122  21.0  Palestinian        Israeli civilians
# 11123  24.0      Israeli    Palestinian civilians
#
# [11124 rows x 3 columns]

# %%
df_killed_by = df[['age', 'citizenship', 'killed_by']]
df_killed_by.describe(include='all')
# Out:
#                  age  citizenship                killed_by
# count   10995.000000        11124                    11124
# unique           NaN            4                        3
# top              NaN  Palestinian  Israeli security forces
# freq             NaN        10092                    10000
# mean       26.745703          NaN                      NaN
# std        13.780548          NaN                      NaN
# min         1.000000          NaN                      NaN
# 25%        19.000000          NaN                      NaN
# 50%        23.000000          NaN                      NaN
# 75%        31.000000          NaN                      NaN
# max       112.000000          NaN                      NaN

# %% [markdown]
# # Seleção de linhas

# %%
df[ df.age < 18 ]
# Out:
#                                    name date_of_event   age  citizenship  \
# 2      'Abdallah 'Imad Sa'ed Abu Hassan    2023-09-22  16.0  Palestinian
# 4          Raafat 'Omar Ahmad Khamaisah    2023-09-19  15.0  Palestinian
# 9             Milad Munzer Wajih a-Ra'i    2023-09-09  15.0  Palestinian
# 10       Muhammad Yusef Isma'il Zbeidat    2023-09-05  16.0  Palestinian
# 14          Khaled Samer Fadel a-Z'anin    2023-08-30  14.0  Palestinian
# ...                                 ...           ...   ...          ...
# 11062                      Yosef Ishran    2001-05-09  14.0      Israeli
# 11063                       Kobi Mandel    2001-05-09  14.0      Israeli
# 11070                   Naftali Lanzkom    2001-03-28  13.0      Israeli
# 11071            Eliran Rosenberg Zayat    2001-03-28  15.0      Israeli
# 11087                       Ophir Rahum    2001-01-17  16.0      Israeli
#
#                 event_location event_location_district event_location_region  \
# 2                     Kfar Dan                   Jenin             West Bank
# 4                   Jenin R.C.                   Jenin             West Bank
# 9               al-'Arrub R.C.                  Hebron             West Bank
# 10                     Argaman                 Jericho             West Bank
# 14                 al-Musrarah          East Jerusalem             West Bank
# ...                        ...                     ...                   ...
# 11062                    Tekoa               Bethlehem             West Bank
# 11063                    Tekoa               Bethlehem             West Bank
# 11070  Neve Yemin Intersection                  Israel                Israel
# 11071  Neve Yemin Intersection                  Israel                Israel
# 11087                 al-Birah    Ramallah and al-Bira             West Bank
#
#       date_of_death gender took_part_in_the_hostilities place_of_residence  \
# 2        2023-09-22      M                          NaN           al-Yamun
# 4        2023-09-19      M                          NaN              Jenin
# 9        2023-09-09      M                          NaN     al-'Arrub Camp
# 10       2023-09-05      M                          NaN          a-Zbeidat
# 14       2023-08-30      M                          NaN        Beit Hanina
# ...             ...    ...                          ...                ...
# 11062    2001-05-08      M                     Israelis              Tekoa
# 11063    2001-05-09      M                     Israelis              Tekoa
# 11070    2001-03-28      M                     Israelis        Petah Tikva
# 11071    2001-03-28      M                     Israelis      Giv'at Shmuel
# 11087    2001-01-17      M                     Israelis           Ashkelon
#
#       place_of_residence_district type_of_injury       ammunition  \
# 2                           Jenin        gunfire  live ammunition
# 4                           Jenin        gunfire  live ammunition
# 9                          Hebron        gunfire  live ammunition
# 10                        Jericho        gunfire  live ammunition
# 14                 East Jerusalem       stabbing  live ammunition
# ...                           ...            ...              ...
# 11062                   Bethlehem        beating              NaN
# 11063                   Bethlehem        beating              NaN
# 11070                      Israel      explosion   explosive belt
# 11071                      Israel      explosion   explosive belt
# 11087                      Israel        gunfire              NaN
#
#                      killed_by  \
# 2      Israeli security forces
# 4      Israeli security forces
# 9      Israeli security forces
# 10     Israeli security forces
# 14     Israeli security forces
# ...                        ...
# 11062    Palestinian civilians
# 11063    Palestinian civilians
# 11070    Palestinian civilians
# 11071    Palestinian civilians
# 11087    Palestinian civilians
#
#                                                    notes
# 2      Fatally shot by soldiers while firing at them ...
# 4      Wounded by soldiers’ gunfire after running awa...
# 9      Fatally shot by a soldier after throwing two M...
# 10     Fatally shot by Border Police officers after f...
# 14     Fatally shot by a Border Police officer after,...
# ...                                                  ...
# 11062  Killed by Palestinians who crushed his skull w...
# 11063  Killed by Palestinians who crushed his skull w...
# 11070  Killed in a suicide bombing at a gas station n...
# 11071  Killed in a suicide bombing at a gas station n...
# 11087  Killed by gunfire at close range after he was ...
#
# [2239 rows x 16 columns]

# %%
df18 = df[ df.age < 18 ]

# %%
df18.age.mean()
# Out:
# 12.393925859758822

# %%
df[ df.age < 18 ].age.mean()
# Out:
# 12.393925859758822

# %%
len(df[ df.age < 18 ])
# Out:
# 2239

# %%
len(df[ df.age < 18 ]) / len(df)
# Out:
# 0.20127651923768428

# %%
len(df[ (df.age < 18) & (df.gender == 'F') ]) / len(df)
# Out:
# 0.043329737504494786

# %%
len(df[ (df.age < 18) & (df.gender == 'M') ]) / len(df)
# Out:
# 0.1579467817331895

# %%
len(df[ (df.gender == 'F') ]) / len(df)
# Out:
# 0.12792161093131968

# %% [markdown]
# # Seleção de linhas e colunas

# %%
df[ df.gender == 'F' ][['age', 'gender', 'citizenship', 'killed_by']]
# Out:
#         age gender  citizenship                killed_by
# 16     40.0      F      Israeli    Palestinian civilians
# 73     14.0      F  Palestinian  Israeli security forces
# 99     82.0      F      Israeli    Palestinian civilians
# 114    17.0      F  Palestinian  Israeli security forces
# 121    44.0      F  Palestinian  Israeli security forces
# ...     ...    ...          ...                      ...
# 11104  21.0      F      Israeli    Palestinian civilians
# 11106  35.0      F      Israeli    Palestinian civilians
# 11111  42.0      F      Israeli    Palestinian civilians
# 11113  25.0      F      Israeli    Palestinian civilians
# 11114  28.0      F      Israeli    Palestinian civilians
#
# [1423 rows x 4 columns]

# %% [markdown]
# # **CASE: Cigarettes**

# %% [markdown]
# ## Read...

# %%
df = pd.read_csv('https://vincentarelbundock.github.io/Rdatasets/csv/AER/CigarettesSW.csv')
df = df.drop(columns='rownames')
df.head()
# Out:
#   state  year    cpi  population       packs     income        tax  \
# 0    AL  1985  1.076     3973000  116.486282   46014968  32.500004
# 1    AR  1985  1.076     2327000  128.534592   26210736  37.000000
# 2    AZ  1985  1.076     3184000  104.522614   43956936  31.000000
# 3    CA  1985  1.076    26444000  100.363037  447102816  26.000000
# 4    CO  1985  1.076     3209000  112.963539   49466672  31.000000
#
#         price       taxs
# 0  102.181671  33.348335
# 1  101.474998  37.000000
# 2  108.578751  36.170418
# 3  107.837341  32.104000
# 4   94.266663  31.000000

# %% [markdown]
# ## Inspeção inicial dos dados

# %%
df.shape
# Out:
# (96, 9)

# %%
len(df)
# Out:
# 96

# %%
df.describe(include='all')
# Out:
#        state         year        cpi    population       packs        income  \
# count     96    96.000000  96.000000  9.600000e+01   96.000000  9.600000e+01
# unique    48          NaN        NaN           NaN         NaN           NaN
# top       AL          NaN        NaN           NaN         NaN           NaN
# freq       2          NaN        NaN           NaN         NaN           NaN
# mean     NaN  1990.000000   1.300000  5.168866e+06  109.182424  9.987874e+07
# std      NaN     5.026247   0.225176  5.442345e+06   25.871305  1.205411e+08
# min      NaN  1985.000000   1.076000  4.784470e+05   49.272198  6.887097e+06
# 25%      NaN  1985.000000   1.076000  1.622606e+06   92.450159  2.552038e+07
# 50%      NaN  1990.000000   1.300000  3.697472e+06  110.160660  6.166164e+07
# 75%      NaN  1995.000000   1.524000  5.901500e+06  123.523010  1.273140e+08
# max      NaN  1995.000000   1.524000  3.149352e+07  197.993988  7.714701e+08
#
#               tax       price        taxs
# count   96.000000   96.000000   96.000000
# unique        NaN         NaN         NaN
# top           NaN         NaN         NaN
# freq          NaN         NaN         NaN
# mean    42.684028  143.447938   48.326150
# std     16.138088   43.887444   19.332215
# min     18.000000   84.967995   21.268000
# 25%     31.000000  102.706415   34.770125
# 50%     37.000002  137.720383   41.048750
# 75%     50.875000  176.150471   59.476979
# max     99.000000  240.849670  112.633003

# %%
df.dtypes
# Out:
# state          object
# year            int64
# cpi           float64
# population      int64
# packs         float64
# income          int64
# tax           float64
# price         float64
# taxs          float64
# dtype: object

# %% [markdown]
# ## Selecionando uma Coluna

# %%
df.population
# Out:
# 0      3973000
# 1      2327000
# 2      3184000
# 3     26444000
# 4      3209000
#         ...
# 91      582827
# 92     5431024
# 93     5137004
# 94     1820560
# 95      478447
# Name: population, Length: 96, dtype: int64

# %%
df['population']
# Out:
# 0      3973000
# 1      2327000
# 2      3184000
# 3     26444000
# 4      3209000
#         ...
# 91      582827
# 92     5431024
# 93     5137004
# 94     1820560
# 95      478447
# Name: population, Length: 96, dtype: int64

# %%
col = 'population'
df[col]
# Out:
# 0      3973000
# 1      2327000
# 2      3184000
# 3     26444000
# 4      3209000
#         ...
# 91      582827
# 92     5431024
# 93     5137004
# 94     1820560
# 95      478447
# Name: population, Length: 96, dtype: int64

# %%
df.columns
# Out:
# Index(['state', 'year', 'cpi', 'population', 'packs', 'income', 'tax', 'price',
#        'taxs'],
#       dtype='object')

# %%
for c in ['population', 'packs', 'income']:
  print(c, ' mean = ', df[c].mean())
# Out:
# population  mean =  5168866.322916667
# packs  mean =  109.18242386976878
# income  mean =  99878735.73958333

# %%
df.population.mean(), df.population.std(), df.population.sum(), df.population.max(),
# Out:
# (5168866.322916667, 5442344.657406039, 496211167, 31493524)

# %%
df['population'].var()
# Out:
# 29619115369996.047

# %%
df['state'].unique()
# Out:
# array(['AL', 'AR', 'AZ', 'CA', 'CO', 'CT', 'DE', 'FL', 'GA', 'IA', 'ID',
#        'IL', 'IN', 'KS', 'KY', 'LA', 'MA', 'MD', 'ME', 'MI', 'MN', 'MO',
#        'MS', 'MT', 'NC', 'ND', 'NE', 'NH', 'NJ', 'NM', 'NV', 'NY', 'OH',
#        'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX', 'UT', 'VA', 'VT',
#        'WA', 'WI', 'WV', 'WY'], dtype=object)

# %%
df['state'].nunique()
# Out:
# 48

# %%
df.state.value_counts()
# Out:
# AL    2
# AR    2
# NE    2
# NH    2
# NJ    2
# NM    2
# NV    2
# NY    2
# OH    2
# OK    2
# OR    2
# PA    2
# RI    2
# SC    2
# SD    2
# TN    2
# TX    2
# UT    2
# VA    2
# VT    2
# WA    2
# WI    2
# WV    2
# ND    2
# NC    2
# MT    2
# IL    2
# AZ    2
# CA    2
# CO    2
# CT    2
# DE    2
# FL    2
# GA    2
# IA    2
# ID    2
# IN    2
# MS    2
# KS    2
# KY    2
# LA    2
# MA    2
# MD    2
# ME    2
# MI    2
# MN    2
# MO    2
# WY    2
# Name: state, dtype: int64

# %% [markdown]
# ## Selecionando várias colunas

# %%
df.columns
# Out:
# Index(['state', 'year', 'cpi', 'population', 'packs', 'income', 'tax', 'price',
#        'taxs'],
#       dtype='object')

# %%
df[ ['state', 'year', 'population'] ]
# Out:
#    state  year  population
# 0     AL  1985     3973000
# 1     AR  1985     2327000
# 2     AZ  1985     3184000
# 3     CA  1985    26444000
# 4     CO  1985     3209000
# ..   ...   ...         ...
# 91    VT  1995      582827
# 92    WA  1995     5431024
# 93    WI  1995     5137004
# 94    WV  1995     1820560
# 95    WY  1995      478447
#
# [96 rows x 3 columns]

# %%
pop = df[ ['state', 'year', 'population'] ]
pop.head()
# Out:
#   state  year  population
# 0    AL  1985     3973000
# 1    AR  1985     2327000
# 2    AZ  1985     3184000
# 3    CA  1985    26444000
# 4    CO  1985     3209000

# %% [markdown]
# ## Seleção de linhas

# %%
df[ df.population > 20000000 ]
# Out:
#    state  year    cpi  population       packs     income   tax       price  \
# 3     CA  1985  1.076    26444000  100.363037  447102816  26.0  107.837341
# 51    CA  1995  1.524    31493524   56.859306  771470144  61.0  210.504669
#
#          taxs
# 3   32.104000
# 51  74.771332

# %%
df[ (df.state == 'CA') | (df.state == 'VT') ] # AND = &
# Out:
#    state  year    cpi  population       packs     income   tax       price  \
# 3     CA  1985  1.076    26444000  100.363037  447102816  26.0  107.837341
# 43    VT  1985  1.076      530000  145.283020    6887097  33.0  100.983337
# 51    CA  1995  1.524    31493524   56.859306  771470144  61.0  210.504669
# 91    VT  1995  1.524      582827  122.334755   12448607  44.0  175.638748
#
#          taxs
# 3   32.104000
# 43  33.000000
# 51  74.771332
# 91  52.363750

# %%
df_CAVT = df[ (df.state == 'CA') | (df.state == 'VT') ]
df_CAVT.describe(include='all')
# Out:
#        state         year       cpi    population       packs        income  \
# count      4     4.000000  4.000000  4.000000e+00    4.000000  4.000000e+00
# unique     2          NaN       NaN           NaN         NaN           NaN
# top       CA          NaN       NaN           NaN         NaN           NaN
# freq       2          NaN       NaN           NaN         NaN           NaN
# mean     NaN  1990.000000  1.300000  1.476259e+07  106.210030  3.094772e+08
# std      NaN     5.773503  0.258653  1.653291e+07   37.666902  3.706593e+08
# min      NaN  1985.000000  1.076000  5.300000e+05   56.859306  6.887097e+06
# 25%      NaN  1985.000000  1.076000  5.696202e+05   89.487104  1.105823e+07
# 50%      NaN  1990.000000  1.300000  1.351341e+07  111.348896  2.297757e+08
# 75%      NaN  1995.000000  1.524000  2.770638e+07  128.071821  5.281946e+08
# max      NaN  1995.000000  1.524000  3.149352e+07  145.283020  7.714701e+08
#
#               tax       price       taxs
# count    4.000000    4.000000   4.000000
# unique        NaN         NaN        NaN
# top           NaN         NaN        NaN
# freq          NaN         NaN        NaN
# mean    41.000000  148.741024  48.059771
# std     15.253415   53.204459  20.111481
# min     26.000000  100.983337  32.104000
# 25%     31.250000  106.123840  32.776000
# 50%     38.500000  141.738045  42.681875
# 75%     48.250000  184.355228  57.965646
# max     61.000000  210.504669  74.771332

# %% [markdown]
# ## Selecionar linhas E colunas

# %%
df[ (df.state == 'CA') | (df.state == 'VT') ][ ['state', 'year', 'population'] ]
# Out:
#    state  year  population
# 3     CA  1985    26444000
# 43    VT  1985      530000
# 51    CA  1995    31493524
# 91    VT  1995      582827

# %%
df[ (df.state == 'CA') | (df.state == 'VT') ].population
# Out:
# 3     26444000
# 43      530000
# 51    31493524
# 91      582827
# Name: population, dtype: int64

# %%
df[ (df.state == 'CA') | (df.state == 'VT') ].population.mean()
# Out:
# 14762587.75

# %% [markdown]
# ## Qual o percentual de dados do ano de 1985?

# %%
len( df[ df.year == 1985 ] ) / len(df)
# Out:
# 0.5

# %% [markdown]
# ## Qual o percentual da população da CA do total no ano de 1995?

# %%
df[ (df.state == 'CA') & (df.year == 1995) ]['population']
# Out:
# 51    31493524
# Name: population, dtype: int64

# %%
df['population'].sum()
# Out:
# 496211167

# %%
df[ (df.state == 'CA') & (df.year == 1995) ]['population'] / df['population'].sum()
# Out:
# 51    0.063468
# Name: population, dtype: float64

# %% [markdown]
# # **CASE: Guns**

# %% [markdown]
# # Starting...

# %%
guns = pd.read_csv('https://vincentarelbundock.github.io/Rdatasets/csv/AER/Guns.csv')
guns.head()
# Out:
#    rownames  year  violent  murder  robbery  prisoners      afam      cauc  \
# 0         1  1977    414.4    14.2     96.8         83  8.384873  55.12291
# 1         2  1978    419.1    13.3     99.1         94  8.352101  55.14367
# 2         3  1979    413.3    13.2    109.5        144  8.329575  55.13586
# 3         4  1980    448.5    13.2    132.1        141  8.408386  54.91259
# 4         5  1981    470.5    11.9    126.5        149  8.483435  54.92513
#
#        male  population    income   density    state law
# 0  18.17441    3.780403  9563.148  0.074552  Alabama  no
# 1  17.99408    3.831838  9932.000  0.075567  Alabama  no
# 2  17.83934    3.866248  9877.028  0.076245  Alabama  no
# 3  17.73420    3.900368  9541.428  0.076829  Alabama  no
# 4  17.67372    3.918531  9548.351  0.077187  Alabama  no

# %%
guns.law.value_counts()
# Out:
# no     888
# yes    285
# Name: law, dtype: int64

# %%
guns.income.mean()
# Out:
# 13724.796065643648

# %% [markdown]
# # Read

# %%
df = pd.read_csv('https://vincentarelbundock.github.io/Rdatasets/csv/AER/Guns.csv')
df.drop(columns='Unnamed: 0',inplace=True)
display( df.head() )
# Out:
#    year  violent  murder  robbery  prisoners      afam      cauc      male  \
# 0  1977    414.4    14.2     96.8         83  8.384873  55.12291  18.17441
# 1  1978    419.1    13.3     99.1         94  8.352101  55.14367  17.99408
# 2  1979    413.3    13.2    109.5        144  8.329575  55.13586  17.83934
# 3  1980    448.5    13.2    132.1        141  8.408386  54.91259  17.73420
# 4  1981    470.5    11.9    126.5        149  8.483435  54.92513  17.67372
#
#    population    income   density    state law
# 0    3.780403  9563.148  0.074552  Alabama  no
# 1    3.831838  9932.000  0.075567  Alabama  no
# 2    3.866248  9877.028  0.076245  Alabama  no
# 3    3.900368  9541.428  0.076829  Alabama  no
# 4    3.918531  9548.351  0.077187  Alabama  no

# %%
display( df )
# Out:
#       year  violent  murder  robbery  prisoners      afam      cauc      male  \
# 0     1977    414.4    14.2     96.8         83  8.384873  55.12291  18.17441
# 1     1978    419.1    13.3     99.1         94  8.352101  55.14367  17.99408
# 2     1979    413.3    13.2    109.5        144  8.329575  55.13586  17.83934
# 3     1980    448.5    13.2    132.1        141  8.408386  54.91259  17.73420
# 4     1981    470.5    11.9    126.5        149  8.483435  54.92513  17.67372
# ...    ...      ...     ...      ...        ...       ...       ...       ...
# 1168  1995    254.2     2.1     17.9        254  1.485849  73.71621  15.37098
# 1169  1996    249.7     3.3     20.4        289  1.521814  73.85796  15.44601
# 1170  1997    255.2     3.5     17.7        310  1.527818  73.92731  15.49400
# 1171  1998    247.6     4.8     16.2        326  1.558396  73.98515  15.51021
# 1172  1999    232.3     2.3     15.4        327  1.613004  74.04952  15.48013
#
#       population     income   density    state  law
# 0       3.780403   9563.148  0.074552  Alabama   no
# 1       3.831838   9932.000  0.075567  Alabama   no
# 2       3.866248   9877.028  0.076245  Alabama   no
# 3       3.900368   9541.428  0.076829  Alabama   no
# 4       3.918531   9548.351  0.077187  Alabama   no
# ...          ...        ...       ...      ...  ...
# 1168    0.478447  14070.160  0.004927  Wyoming  yes
# 1169    0.480085  14032.230  0.004944  Wyoming  yes
# 1170    0.480031  14790.980  0.004943  Wyoming  yes
# 1171    0.480045  15225.510  0.004944  Wyoming  yes
# 1172    0.479602  15765.070  0.004939  Wyoming  yes
#
# [1173 rows x 13 columns]

# %% [markdown]
# # Exploração Inicial

# %%
df.shape
# Out:
# (1173, 13)

# %%
len(df)
# Out:
# 1173

# %%
df.dtypes
# Out:
# year            int64
# violent       float64
# murder        float64
# robbery       float64
# prisoners       int64
# afam          float64
# cauc          float64
# male          float64
# population    float64
# income        float64
# density       float64
# state          object
# law            object
# dtype: object

# %%
df.describe(include='all')
# Out:
#                year      violent       murder      robbery    prisoners  \
# count   1173.000000  1173.000000  1173.000000  1173.000000  1173.000000
# unique          NaN          NaN          NaN          NaN          NaN
# top             NaN          NaN          NaN          NaN          NaN
# freq            NaN          NaN          NaN          NaN          NaN
# mean    1988.000000   503.074680     7.665132   161.820205   226.579710
# std        6.636079   334.277194     7.522710   170.509962   178.888094
# min     1977.000000    47.000000     0.200000     6.400000    19.000000
# 25%     1982.000000   283.100000     3.700000    71.100000   114.000000
# 50%     1988.000000   443.000000     6.400000   124.100000   187.000000
# 75%     1994.000000   650.900000     9.800000   192.700000   291.000000
# max     1999.000000  2921.800000    80.600000  1635.100000  1913.000000
#
#                afam         cauc         male   population        income  \
# count   1173.000000  1173.000000  1173.000000  1173.000000   1173.000000
# unique          NaN          NaN          NaN          NaN           NaN
# top             NaN          NaN          NaN          NaN           NaN
# freq            NaN          NaN          NaN          NaN           NaN
# mean       5.336217    62.945432    16.081127     4.816341  13724.796066
# std        4.885688     9.761527     1.732143     5.252115   2554.542334
# min        0.248207    21.780430    12.213680     0.402753   8554.884000
# 25%        2.202196    59.939700    14.653370     1.187706  11934.760000
# 50%        4.026213    65.061280    15.895170     3.271332  13401.550000
# 75%        6.850673    69.200100    17.525710     5.685611  15271.010000
# max       26.979570    76.525750    22.352690    33.145120  23646.710000
#
#             density    state   law
# count   1173.000000     1173  1173
# unique          NaN       51     2
# top             NaN  Alabama    no
# freq            NaN       23   888
# mean       0.352038      NaN   NaN
# std        1.355472      NaN   NaN
# min        0.000707      NaN   NaN
# 25%        0.031911      NaN   NaN
# 50%        0.081569      NaN   NaN
# 75%        0.177718      NaN   NaN
# max       11.102120      NaN   NaN

# %% [markdown]
# # Seleção de 1 atributo

# %%
df.income
# Out:
# 0        9563.148
# 1        9932.000
# 2        9877.028
# 3        9541.428
# 4        9548.351
#           ...
# 1168    14070.160
# 1169    14032.230
# 1170    14790.980
# 1171    15225.510
# 1172    15765.070
# Name: income, Length: 1173, dtype: float64

# %%
sns.histplot(df.income)

plt.show()

# %%
df['income'] # Série de dados, somente valores
# Out:
# 0        9563.148
# 1        9932.000
# 2        9877.028
# 3        9541.428
# 4        9548.351
#           ...
# 1168    14070.160
# 1169    14032.230
# 1170    14790.980
# 1171    15225.510
# 1172    15765.070
# Name: income, Length: 1173, dtype: float64

# %%
df[['income']] # Dataframe, ou tabela, com 1 coluna
# Out:
#          income
# 0      9563.148
# 1      9932.000
# 2      9877.028
# 3      9541.428
# 4      9548.351
# ...         ...
# 1168  14070.160
# 1169  14032.230
# 1170  14790.980
# 1171  15225.510
# 1172  15765.070
#
# [1173 rows x 1 columns]

# %%
df.income.mean()
# Out:
# 13724.796065643648

# %%
df['income'].std()
# Out:
# 2554.542334423021

# %%
df[['income']].quantile([0.25,0.75])
# Out:
#         income
# 0.25  11934.76
# 0.75  15271.01

# %%
df.income.var()
# Out:
# 6525686.538359419

# %%
df.year.value_counts()
# Out:
# 1977    51
# 1989    51
# 1998    51
# 1997    51
# 1996    51
# 1995    51
# 1994    51
# 1993    51
# 1992    51
# 1991    51
# 1990    51
# 1988    51
# 1978    51
# 1987    51
# 1986    51
# 1985    51
# 1984    51
# 1983    51
# 1982    51
# 1981    51
# 1980    51
# 1979    51
# 1999    51
# Name: year, dtype: int64

# %%
df.year.unique()
# Out:
# array([1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987,
#        1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998,
#        1999])

# %%
df.state.unique()
# Out:
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'District of Columbia',
#        'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana',
#        'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland',
#        'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi',
#        'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire',
#        'New Jersey', 'New Mexico', 'New York', 'North Carolina',
#        'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania',
#        'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee',
#        'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming'], dtype=object)

# %% [markdown]
# # Seleção de linhas

# %%
df.columns
# Out:
# Index(['year', 'violent', 'murder', 'robbery', 'prisoners', 'afam', 'cauc',
#        'male', 'population', 'income', 'density', 'state', 'law'],
#       dtype='object')

# %%
df[ df.state == 'Alaska' ]
# Out:
#     year  violent  murder  robbery  prisoners      afam      cauc      male  \
# 23  1977    443.2    10.8     96.8         63  7.835672  62.14130  22.35269
# 24  1978    441.9    12.9     91.3         75  7.945618  62.65009  22.05606
# 25  1979    491.1    13.3    109.6        127  8.057296  63.09599  21.97401
# 26  1980    436.0     8.9     81.8        133  8.123558  62.72060  21.55065
# 27  1981    615.8    14.6    114.6        143  8.153878  62.80371  21.01661
# 28  1982    623.7    18.5    133.8        170  8.149489  62.89593  20.32379
# 29  1983    613.8    13.8     97.1        194  8.114173  62.86964  19.54211
# 30  1984    621.6    11.6    109.4        219  8.094755  62.41428  18.85155
# 31  1985    581.8     9.8     92.9        252  8.053830  61.88262  18.22919
# 32  1986    570.4     8.6     88.0        288  8.082400  61.26970  17.81123
# 33  1987    455.4    10.1     73.1        306  8.185459  60.43927  17.49717
# 34  1988    522.8     5.7     72.9        339  8.392160  60.09351  17.20629
# 35  1989    497.7     8.0     67.6        355  8.556108  59.82404  17.13378
# 36  1990    524.5     7.5     76.7        361  8.630677  60.08334  16.99975
# 37  1991    613.9     7.4    113.2        348  8.526665  60.35909  16.56165
# 38  1992    660.5     7.5    109.0        345  8.534543  60.75548  16.34584
# 39  1993    760.8     9.0    122.4        327  8.630754  60.76018  16.19282
# 40  1994    766.3     6.3    146.2        446  8.593396  60.87202  15.97539
# 41  1995    770.9     9.1    155.1        317  8.624999  61.20048  15.75818
# 42  1996    727.7     7.4    117.0        338  8.752260  61.23177  15.81950
# 43  1997    701.1     8.9    106.4        383  8.834417  61.00919  15.98483
# 44  1998    653.9     6.7     86.6        420  8.933932  60.74545  16.30562
# 45  1999    631.5     8.6     91.4        413  8.986603  60.55464  16.63180
#
#     population    income   density   state  law
# 23    0.403437  20296.83  0.000708  Alaska   no
# 24    0.404764  19044.99  0.000711  Alaska   no
# 25    0.402753  18115.89  0.000707  Alaska   no
# 26    0.405315  17901.66  0.000710  Alaska   no
# 27    0.418488  18075.23  0.000733  Alaska   no
# 28    0.449611  18967.13  0.000788  Alaska   no
# 29    0.488417  19045.00  0.000856  Alaska   no
# 30    0.513703  18590.22  0.000900  Alaska   no
# 31    0.532492  18705.20  0.000933  Alaska   no
# 32    0.544269  17906.39  0.000954  Alaska   no
# 33    0.539310  16955.92  0.000945  Alaska   no
# 34    0.541982  16740.64  0.000950  Alaska   no
# 35    0.547153  17285.38  0.000959  Alaska   no
# 36    0.553120  17311.88  0.000970  Alaska   no
# 37    0.569273  17005.98  0.000998  Alaska   no
# 38    0.587073  16978.23  0.001029  Alaska   no
# 39    0.596993  17067.91  0.001047  Alaska   no
# 40    0.600624  16970.02  0.001053  Alaska   no
# 41    0.601345  16871.89  0.001054  Alaska  yes
# 42    0.604918  16546.19  0.001061  Alaska  yes
# 43    0.608846  16816.68  0.001068  Alaska  yes
# 44    0.615205  17077.45  0.001079  Alaska  yes
# 45    0.619500  17120.14  0.001086  Alaska  yes

# %%
Alaska = df[ df.state == 'Alaska' ]

# %%
Alaska.head()
# Out:
#     year  violent  murder  robbery  prisoners      afam      cauc      male  \
# 23  1977    443.2    10.8     96.8         63  7.835672  62.14130  22.35269
# 24  1978    441.9    12.9     91.3         75  7.945618  62.65009  22.05606
# 25  1979    491.1    13.3    109.6        127  8.057296  63.09599  21.97401
# 26  1980    436.0     8.9     81.8        133  8.123558  62.72060  21.55065
# 27  1981    615.8    14.6    114.6        143  8.153878  62.80371  21.01661
#
#     population    income   density   state law
# 23    0.403437  20296.83  0.000708  Alaska  no
# 24    0.404764  19044.99  0.000711  Alaska  no
# 25    0.402753  18115.89  0.000707  Alaska  no
# 26    0.405315  17901.66  0.000710  Alaska  no
# 27    0.418488  18075.23  0.000733  Alaska  no

# %%
Alaska.income.mean()
# Out:
# 17712.906521739133

# %%
df[ df.state == 'Alaska' ].income.mean()
# Out:
# 17712.906521739133

# %%
df[ df.state == 'Alaska' ]['income'].mean()
# Out:
# 17712.906521739133

# %%
df[ df.state == 'Alaska' ][['income']].mean()
# Out:
# income    17712.906522
# dtype: float64

# %% [markdown]
# # Proporções

# %%
len(df)
# Out:
# 1173

# %%
df.shape[0]
# Out:
# 1173

# %%
df.law.value_counts()
# Out:
# no     888
# yes    285
# Name: law, dtype: int64

# %%
len( df[ df.law == 'yes' ] )
# Out:
# 285

# %%
len( df[ df.law == 'yes' ] ) / len(df)
# Out:
# 0.24296675191815856
